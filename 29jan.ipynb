# %%
Ques1: Who developed Python Programming Language? 

Ans:  Python was developed by Guido van Rossum



Ques 2: Which type of Programming does Python support? 

Ans: Python is a multi-paradigm programming language. Object-oriented programming and structured programming are fully supported.


Ques 3: Is Python case sensitive when dealing with identifiers? 
Ans:  Yes, Python is case-sensitive when dealing with identifiers.
       This means that variable names, function names, 
       and other identifiers must be used consistently with respect to their capitalization.
        
 

Ques 4: What is the correct extension of the Python file? 
Ans : .py


Ques 5:  Is Python code compiled or interpreted? 
Ans: Python is an interpreted language



Ques 6: Name a few blocks of code used to define in Python language?
Ans: A Python program is constructed from code blocks. A block is a piece of Python program text that is executed as a unit. 
     The following are blocks: a module, a function body, and a class definition.

 
Ques 7: State a character used to give single-line comments in Python?
Ans: n Python, we use the hash symbol # to write a single-line comment.


Ques 8:  Mention functions which can help us to find the version of python that we are currently working on?
Ans: The function sys. version can help us to find the version of python that we are currently working on.


Ques 9 : Python supports the creation of anonymous functions at runtime, using a construct called 
Ans: Lambda

Question 10: What does pip stand for python? 
ans: Preferred Installer Program

Ques: Mention a few built-in functions in python? 
Ans: print( ) function.
type( ) function.
input( ) function.
abs( ) function.
pow( ) function.
dir( ) function.
sorted( ) function.


Ques 12: What is the maximum possible length of an identifier in Python? 
Ans: 79 characters


Ques 13:  What are the benefits of using Python? 
Ans: Versatility and Flexibility. ...
Community and Support. ...
Integration and Compatibility. ...
Speed of Development. ...
Open Source Advantage. ...
Machine Learning and AI. ...


Ques 14: How is memory managed in Python? 
Ans:
